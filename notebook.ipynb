# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [ILHAM PRAJA SAPUTRA]
# - **Email:** [ilhampraja99@gmail.com]
# - **ID Dicoding:** [ilhampraja]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana Performa Penjualan dan Revenue Perusahaan dalam Beberapa Bulan Terakhir?
# - Pertanyaan 2: Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?
# - Pertanyaan 3: Bagaimana Demografi Pelanggan yang Kita Miliki berdasarkan State?
# - Pertanyaan 4: Tipe pembayaran jenis apa yang paling banyak digunakan pelanggan?
# - Pertanyaan 5: Seberapa puas pelanggan dalam menggunakan layanan?
# - Pertanyaan 6: Berapa banyak pengiriman barang yang terlambat?
# - Pertanyaan 7: Kapan terakhir pelanggan melakukan transaksi?
# - Pertanyaan 8: Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# - Pertanyaan 9: Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("data/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geo_df = pd.read_csv("data/geolocation_dataset.csv")
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
item_df = pd.read_csv("data/order_items_dataset.csv")
item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
payments_df = pd.read_csv("data/order_payments_dataset.csv")
payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
review_df = pd.read_csv("data/order_reviews_dataset.csv")
review_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_df = pd.read_csv("data/orders_dataset.csv")
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
category_df = pd.read_csv("data/product_category_name_translation.csv")
category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_df = pd.read_csv("data/products_dataset.csv")
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv("data/sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi: ",order_df.duplicated().sum())
order_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
print("Jumlah duplikasi: ",geo_df.duplicated().sum())
geo_df.describe()
# Out:
# Jumlah duplikasi:  261831
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah duplikasi: ",item_df.duplicated().sum())
item_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Jumlah duplikasi: ",payments_df.duplicated().sum())
payments_df.describe()
# Out:
# Jumlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
review_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
review_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("Jumlah duplikasi: ",review_df.duplicated().sum())
review_df.describe()
# Out:
# Jumlah duplikasi:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",order_df.duplicated().sum())
order_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Jumlah duplikasi: ",category_df.duplicated().sum())
category_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
print("Jumlah duplikasi: ",sellers_df.duplicated().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ",product_df.duplicated().sum())
product_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# **Insight**
#
# **DUPLIKASI DATA :**
# - geo_df
#
# **MISSING VALUE :**
# - review_df :review_comment_title dan review_comment_message
# - order_df  : order_approved_at, order_delivered_carrier_date, order_delivered_customer_date
# - product_df : product_category_name,product_name_lenght,product_description_lengh,product_photos_qty
#
# **TIPE DATA :**
# - order_df  : order_purchase_stamp, order_approved_at, order_delivered_carrier_date, order_estimated_delivery dan order_delivered_customer_date
# - item_df   : shipping_limit_date
# - review_df : review_creation_date, review_answer_timestamp, review_score

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 48728  101cabeec1a36f2968ceaa2690b80807  10e9f26949e4821488e156eaf33f5fa6
# 15322  58d6b7ad12ad08c7c8031d623ea2219d  2202f25c6279be61c311a3af46157e32
# 93757  6ca834e14df3fb5924d4e7fe551c80d9  73e1b03fe677803ab302437065bb5cee
# 12753  eeba1dfa84dff855a9bcedcb487549dd  40c7d59d0ca882ee31615c188ee54593
# 89418  df019bb6f0973ea1ace7dbb1568c364a  8d742720a64d27602b567851fbad7798
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 48728    delivered      2017-12-16 15:50:09  2017-12-16 16:14:19
# 15322    delivered      2018-06-19 08:56:08  2018-06-19 09:18:25
# 93757    delivered      2018-02-22 12:21:56  2018-02-22 12:35:40
# 12753    delivered      2017-11-06 10:32:23  2017-11-07 07:30:33
# 89418    delivered      2017-11-12 09:21:20  2017-11-12 09:35:26
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %% [markdown]
# ### Drop order_df bernilai Null

# %%
order_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order_df.dropna(inplace=True)

# %%
order_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ### Drop product_df bernilai Null

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_df.dropna(inplace=True)

# %%
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ### Masalah tipe data

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_estimated_delivery_date", "order_delivered_customer_date"]
 
for column in datetime_columns:
  order_df[column] = pd.to_datetime(order_df[column])

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB

# %%
datetime_columns = ["shipping_limit_date"]
 
for column in datetime_columns:
  item_df[column] = pd.to_datetime(item_df[column])

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
datetime_columns = ["review_creation_date", "review_answer_timestamp"]
 
for column in datetime_columns:
  review_df[column] = pd.to_datetime(review_df[column])

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
review_columns = ["review_score"]

for column in review_columns:
    review_df[column] = review_df[column].astype('object')

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  object
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 5.3+ MB

# %% [markdown]
# ### **Insight**
#
# **DROP DUPLICATE :**
# - geo_df
# - xxx
#
# - Dataset review_df terdapat missing value pada kolom : review_comment_message dan review_comment_title, karena komentar review itu opsional maka menurut saya data tersebut tidak dilakukan Cleaning data.
# - Dataset geo_df terdapat duplikasi data, tidak perlu dicleaning.
# - Dataset order_df terdapat missing value yang tidak dapat disikan, maka akan di drop.
# - Dataset order_df terdapat kolom dengan tipe data yang salah dan telah diperbaiki.
# - Dataset item_df terdapat kolom dengan tipe data yang salah dan telah diperbaiki.
# - Dataset product_df memiliki missing value, maka data tersebut di drop
# - Dataset review_df terdapat kolom salah tipe data, kolom review_score diubah dari tipe data int ke object. Karena merupan data kategorik ordinal

# %%
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# ### Explore customer_df

# %%
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers_df.groupby(by="customer_state").customer_city.nunique().sort_values(ascending=False)
# Out:
# customer_state
# MG    745
# SP    629
# RS    379
# PR    364
# BA    353
# SC    240
# GO    178
# CE    161
# PE    152
# RJ    149
# MA    122
# MT    101
# ES     95
# PB     92
# RN     90
# PA     89
# PI     72
# AL     68
# MS     67
# TO     56
# SE     46
# RO     35
# AC      8
# DF      6
# AP      6
# AM      5
# RR      2
# Name: customer_city, dtype: int64

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# > Customer paling banya berasal dari kota SAO PAULO

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# > Customer paling banyak berasal dari state SP

# %%
order_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              96461                             96461
# unique                             96461                             96461
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         96461                          96461
# ...

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customer_id_in_orders_df = order_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non_Active")
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 28338  125a2560ed26caa1aaa75eebd3f97be1  c6b2942cded5b2da47e32cf285b6d8b5
# 48659  b7f69471fed8a036911323fca290a2c2  5ceed695eeb968efc7959d859a902e00
# 57751  d717f827870337ac0f4c75982011f237  ccb6b2e02765251c6fbfc6fd170aceea
# 52910  edf2cbbe8938f4db1da137cf67b56ac3  89698c8bbd68babe5edec47450537a05
# 1431   33ac5a0d983f8f8905499a9f926086f5  8028fbabf6123c13297c82f4393a4724
#
#        customer_zip_code_prefix    customer_city customer_state      status
# 28338                     13070         campinas             SP      Active
# 48659                      8771  mogi das cruzes             SP      Active
# 57751                     13632     pirassununga             SP      Active
# 52910                     29110       vila velha             ES      Active
# 1431                       1452        sao paulo             SP  Non_Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        96461
# Non_Active     2980
# Name: customer_id, dtype: int64

# %% [markdown]
# >  hanya 8,9% pelangan kita yang belum pernah melakukan order

# %%
# Menghitung jumlah 'Non Active' per state
non_active_counts = (
    customers_df[customers_df['status'] == 'Non_Active']
    .groupby('customer_state')
    .size()
    .sort_values(ascending=False)
)

# Menampilkan state dengan jumlah 'Non Active' terbanyak
print(non_active_counts.head())
# Out:
# customer_state
# SP    1257
# RJ     501
# MG     283
# BA     124
# RS     124
# dtype: int64

# %% [markdown]
# > SP merupakan state dengan customer status yang paling banyak tidak aktif

# %% [markdown]
# ### Explore item_df

# %%
item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
item_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# > harga barang yang dijual berkisar antara 0.8 hingga 6735 dolar, setiap transaksi pelanggan paling banyak membeli 21 buah item dalam satu jenis produk

# %% [markdown]
# ### Explore payment_df

# %%
payments_df.sample(12)
# Out:
#                                order_id  payment_sequential payment_type  \
# 58452  3c1241a1be26ab60ec48baeca3cc7037                   1  credit_card
# 67037  2524a4278af338cc4ba22f64a10d5798                   1  credit_card
# 62858  26bfc6c6251ef7eda55f7bc7f11e9647                   1  credit_card
# 60353  c4d43ff7c0529549e6064083bd2129d3                   1  credit_card
# 57474  f97da0a16b75363e98debcd65fe1253a                   1  credit_card
# 32807  087a471c766adfaa11fd61670213b4c3                   1  credit_card
# 79121  2a0f3e45a35626fe09681315beafbb10                   1  credit_card
# 53976  f65681ae52bf95372fcd66c697752f3d                   1       boleto
# 78860  3069c59ca4d7b71a93c01aa815b34ec3                   2      voucher
# 65233  54a444c922f6fb6c0351d8981d9c5ded                   1  credit_card
# 53920  3523181d27be330ade8446c606e5e924                   1  credit_card
# 27996  3d86c4b9522b58a104b2fca7421713d2                   1  credit_card
#
# ...

# %%
payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# > Tipe pembayaran paling banyak digunakan adalah credit card

# %%
payments_df['total_payment'] = payments_df['payment_installments'] * payments_df['payment_value'] #mencari total payment
payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value  total_payment
# 0                     8          99.33         794.64
# 1                     1          24.39          24.39
# 2                     1          65.71          65.71
# 3                     8         107.78         862.24
# 4                     2         128.45         256.90

# %%
payment_summary = payments_df.groupby('payment_type')['total_payment'].sum() 
print(payment_summary)
# Out:
# payment_type
# boleto          2869361.27
# credit_card    62296369.69
# debit_card       217989.79
# not_defined           0.00
# voucher          379436.87
# Name: total_payment, dtype: float64

# %% [markdown]
# > tipe pembayaran credit card menghasilkan total pembayaran terbesar

# %% [markdown]
# ### Explore review_df

# %%
review_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#   review_score review_comment_title  \
# 0            4                  NaN
# 1            5                  NaN
# 2            5                  NaN
# 3            5                  NaN
# 4            5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN           2018-01-18
# 1                                                NaN           2018-03-10
# 2                                                NaN           2018-02-17
# ...

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  object
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 5.3+ MB

# %%
review_score_counts = review_df.groupby('review_score')['order_id'].nunique()
review_score_counts.head()
# Out:
# review_score
# 1    11393
# 2     3148
# 3     8160
# 4    19098
# 5    57076
# Name: order_id, dtype: int64

# %% [markdown]
# > skor review 5 paling banyak, tingkat kepuasan pelanggan tinggi dalam berbelanja

# %% [markdown]
# ### Explore order_df

# %%
order_df.sample(11)
# Out:
#                                order_id                       customer_id  \
# 73786  ab02e1347f5a89f4142106cad4f9f7f8  d52487b960f7df5994f82f0a5de2fd06
# 72337  82ea82026e50c602a0a88e158b8fa8d4  302e2c173a66a78cce4229248835a524
# 93020  5a07264682e0b8fbb3f166edbbffc6e8  42333d2ab86886576093712fbf1564ce
# 39405  1b03d26a97ac5fda045a6f88d0d88d7a  18d46e1e396620d92cc0acbf564fd572
# 660    fb4c699559386e0b6b970181177d99bd  e7ba6d56b812cb7e8c4a285d95f4e476
# 21840  c6b834f817f95bd7f31d78814dbb14ac  8cb472ad4da26b59f50a5fa1194d47b7
# 4466   69a236fbbc4a603ebfa4468a3bdcb140  1bd6b1b425cc25c6e0c79f68d28fe2fb
# 21823  24011f35927e676f392e9dc0f7a4b06a  8cb5215c25ad0689fc8460e4191233c5
# 28493  cd6426e4690d765ab066e248ae03d67a  6fe0c4aa4fe245ace106e0e4101f60fa
# 66182  727140332cb5607e87e03e1501f636b2  06199a7981ec145069afeb0baf66a49b
# 16530  9125c1064ed28a581538a66da2a84750  e7fa14abbccc3cdab0705a9dc2fac2cc
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
order_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              96461                             96461
# unique                             96461                             96461
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         96461                          96461
# ...

# %%
order_df.order_status.value_counts()
# Out:
# order_status
# delivered    96455
# canceled         6
# Name: count, dtype: int64

# %% [markdown]
# > dari total 96461 hanya 6 order yang canceled

# %%
# Membuat kolom is_late_delivery
order_df['is_late_delivery'] = order_df['order_delivered_customer_date'] > order_df['order_estimated_delivery_date']
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_df.is_late_delivery.value_counts()
# Out:
# is_late_delivery
# False    88635
# True      7826
# Name: count, dtype: int64

# %% [markdown]
# > terdapat 7826 keterlambatan pada pengirman barang

# %%
order_state_city_df = pd.merge(
    left=order_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
order_state_city_df.sample(22)
# Out:
#                                order_id                       customer_id  \
# 26534  88fc6bd429f0b065b3c80ec1e323c890  af6e19f06ecfc197b49e1d1e2d35f2ed
# 64318  00ab210695a17fe10e6b23616ae5bc97  c87e0e6aa4b3321adb017785ff605af2
# 43332  ad1b24e31eda83c8bf2123f3961f588a  1b79c6b65f89bf54aa50921be431b176
# 2752   a62ca1ecd2ebb5a76f2df38e3024c324  63aa5b96f7dafc4bb3b80ee18c32b7f9
# 38076  fc4bcada7517f413ad3d38e7404c9b3f  1334da127df70d32ddf5a1a27c675e65
# 14161  8c2189f32103647dde2d19e9045c2a76  58db7d715512621026cea08f56d283b3
# 38059  d764dbf4808e4b71b8602d2c1655767e  9ff3b4f2efedcb1767dd4bb0ca75049c
# 33024  3453f6956295695e0125cf11b651bce7  feda036b332e007a11cb6399f3bbb806
# 17036  def30b257b8f2ee7c3a6c8ca06695ddf  a08653fb77996ef39f8dca7e4c231fd1
# 58973  0dab9a07f01db0bee87c3affed50eccd  b140d40f39de3e9108b1b4099ce546cc
# 57531  8d29abe41d9157240194d0210b529771  ed066dda2388fced0086629ab3d0c23f
# 42600  0ba1fcf42e40850f464b8ca9b0b5e9fb  fb78d507b1a69fa3058a333371c7371b
# ...

# %%
order_state_city_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    96461
# Name: customer_id, dtype: int64

# %%
columns_to_drop = [
    'order_purchase_timestamp', 
    'order_approved_at', 
    'order_delivered_carrier_date', 
    'order_delivered_customer_date', 
    'order_estimated_delivery_date', 
    'customer_unique_id', 
    'customer_zip_code_prefix'
]
order_state_city_df = order_state_city_df.drop(columns=columns_to_drop)

# %%
order_state_city_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status  is_late_delivery            customer_city customer_state  \
# 0    delivered             False                sao paulo             SP
# 1    delivered             False                barreiras             BA
# 2    delivered             False               vianopolis             GO
# 3    delivered             False  sao goncalo do amarante             RN
# 4    delivered             False              santo andre             SP
#
#    status
# 0  Active
# 1  Active
# 2  Active
# 3  Active
# 4  Active

# %%
order_state_city_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              96461                             96461
# unique                             96461                             96461
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status is_late_delivery customer_city customer_state  status
# count         96461            96461         96461          96461   96461
# unique            2                2          4085             27       1
# top       delivered            False     sao paulo             SP  Active
# freq          96455            88635         15044          40489   96461

# %%
order_state_city_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo             15044
# rio de janeiro         6603
# belo horizonte         2697
# brasilia               2071
# curitiba               1489
#                       ...
# ponto novo                1
# ponto do marambaia        1
# ponto belo                1
# pontes gestal             1
# retirolandia              1
# Name: order_id, Length: 4085, dtype: int64

# %% [markdown]
# > sao paulo merupakan city yang paling banyak melakukan order

# %%
order_state_city_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    40489
# RJ    12351
# MG    11352
# RS     5342
# PR     4923
# SC     3547
# BA     3256
# DF     2080
# ES     1995
# GO     1957
# PE     1593
# CE     1278
# PA      946
# MT      886
# MA      716
# MS      701
# PB      517
# PI      476
# RN      474
# AL      397
# SE      335
# TO      274
# RO      243
# AM      145
# AC       80
# AP       67
# RR       41
# Name: order_id, dtype: int64

# %% [markdown]
# > SP merupakan state yang paling banyak melakukan order

# %% [markdown]
# ### Explore product_df

# %%
product_df.sample(11)
# Out:
#                              product_id             product_category_name  \
# 13746  19dcf909566fad3eb56a49fa80193852  construcao_ferramentas_seguranca
# 30681  fdc3af4045c7316cadde9fda3c335932             instrumentos_musicais
# 11125  ace151a1240f7d1645965f9a9ea6c7e0                      beleza_saude
# 16928  2ea69b98f8a98247adf9aaba9367bddf                        automotivo
# 22847  5dfc5bdca7ee27155face9d4e89201ae                   cama_mesa_banho
# 28271  8b50377e6ef3606c6e606ca0289d5f34                         telefonia
# 13027  83ad269665a5be4f1e69a2f13ab39553                          pet_shop
# 6518   8c5876b1c7768217964f353bc7e64393                         telefonia
# 26091  e1c6e79822274bf6763eb127ea3a15ed                  moveis_decoracao
# 23715  6b0894fbd8143c541f3c40622d8a9603                ferramentas_jardim
# 2629   74e47bd907dc11882c23f4c4ce14031f            informatica_acessorios
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# ...

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  float64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.5+ MB

# %%
product_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32340                 32340
# unique                             32340                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32340.000000                32340.000000        32340.000000
# ...

# %%
variant_product = product_df.groupby('product_category_name')['product_id'].count().sort_values(ascending=False)
variant_product.head()
# Out:
# product_category_name
# cama_mesa_banho          3029
# esporte_lazer            2867
# moveis_decoracao         2657
# beleza_saude             2444
# utilidades_domesticas    2335
# Name: product_id, dtype: int64

# %% [markdown]
# > kategori produk cama mesa banho paling banyak jenis produknya

# %%
product_df.product_category_name.value_counts().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  float64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.5+ MB

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
item_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96461 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
#  8   is_late_delivery               96461 non-null  bool
# dtypes: bool(1), datetime64[ns](5), object(3)
# memory usage: 6.7+ MB

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_item_df = pd.merge(
    left=item_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
product_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
columns_to_drop = [
    'product_name_lenght', 
    'product_description_lenght', 
    'product_photos_qty', 
    'product_weight_g', 
    'product_length_cm', 
    'product_height_cm', 
    'product_width_cm'
]
product_item_df = product_item_df.drop(columns=columns_to_drop)

# %%
product_item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               112650 non-null  object
#  1   order_item_id          112650 non-null  int64
#  2   product_id             112650 non-null  object
#  3   seller_id              112650 non-null  object
#  4   shipping_limit_date    112650 non-null  datetime64[ns]
#  5   price                  112650 non-null  float64
#  6   freight_value          112650 non-null  float64
#  7   product_category_name  111046 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 6.9+ MB

# %%
product_item_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
product_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
product_item_df.groupby(by="product_category_name").order_item_id.sum().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                                  13665
# moveis_decoracao                                 11540
# beleza_saude                                     11081
# esporte_lazer                                     9932
# informatica_acessorios                            9874
#                                                  ...
# portateis_cozinha_e_preparadores_de_alimentos       16
# la_cuisine                                          16
# pc_gamer                                            11
# fashion_roupa_infanto_juvenil                        8
# seguros_e_servicos                                   2
# Name: order_item_id, Length: 73, dtype: int64

# %% [markdown]
# > produk kategori yang paling banyak terjual adalah cama mesa banho, sedangkan yang paling sedikit terjual seguros e servicos

# %%
product_item_df.sort_values(by="price", ascending=False)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# ...                                  ...            ...
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57300   8272b63d03f5f79c56e9e4120aec44ef              4
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
#
#                               product_id                         seller_id  \
# 3556    489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# ...

# %%
product_item_df.groupby(by="product_category_name").agg({
    "product_id": "nunique",
    "order_item_id": "sum",
    "price":  "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                                product_id  order_item_id       price
# product_category_name
# beleza_saude                         2444          11081  1258681.34
# relogios_presentes                   1329           6594  1205005.68
# cama_mesa_banho                      3029          13665  1036988.68
# esporte_lazer                        2867           9932   988048.97
# informatica_acessorios               1639           9874   911954.32
# ...                                   ...            ...         ...
# flores                                 14             37     1110.04
# casa_conforto_2                         5             39      760.27
# cds_dvds_musicais                       1             16      730.00
# fashion_roupa_infanto_juvenil           5              8      569.85
# seguros_e_servicos                      2              2      283.29
#
# [73 rows x 3 columns]

# %% [markdown]
# > kategori produk beleza saude merupakan kategori produk yang paling banyak menyumbang revenue

# %% [markdown]
# ### Explore sellers_df

# %%
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %% [markdown]
# > seller paling banyak berada di kota sao paulo

# %%
sellers_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# > seller paling banyak berada di state SP

# %% [markdown]
# ### **Insight:**
# - Customer paling banya berasal dari kota SAO PAULO
# - Customer paling banyak berasal dari state SP
# - Tipe pembayaran paling banyak digunakan adalah credit card
# - tipe pembayaran credit card menghasilkan total pembayaran terbesar
# - skor review 5 paling banyak, tingkat kepuasan pelanggan tinggi dalam berbelanja
# - dari total 96461 order hanya 6 order yang canceled
# - terdapat 7826 keterlambatan pada pengirman barang
# - kategori produk cama mesa banho paling banyak jenis produknya
# - produk kategori yang paling banyak terjual adalah cama mesa banho, sedangkan yang paling sedikit terjual seguros e servicos
# - seller paling banyak berada di kota sao paulo
# - seller paling banyak berada di state SP
# - hanya 8,9% pelangan kita yang belum pernah melakukan order
# - harga barang yang dijual berkisar antara 0.8 hingga 6735 dolar
# - setiap transaksi pelanggan paling banyak membeli 21 buah item dalam satu jenis produk
# - sao paulo merupakan city yang paling banyak melakukan order
# - SP merupakan state yang paling banyak melakukan order
# - SP merupakan state dengan customer status yang paling banyak tidak aktif
# - kategori produk beleza saude merupakan kategori produk yang paling banyak menyumbang revenue

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana Performa Penjualan dan Revenue Perusahaan dalam Beberapa Bulan Terakhir

# %%
revenue_df = pd.merge(
    left=order_df,
    right=product_item_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
revenue_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
monthly_orders_df = revenue_df.resample(rule='M', on='order_delivered_customer_date').agg({
    "order_id": "nunique",
    "price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)
monthly_orders_df.head(10)
# Out:
#   order_delivered_customer_date  order_count    revenue
# 0                       2016-10          208   30334.13
# 1                       2016-11           60    9994.18
# 2                       2016-12            4     758.86
# 3                       2017-01          282   33559.13
# 4                       2017-02         1350  198863.39
# 5                       2017-03         2370  334301.67
# 6                       2017-04         1849  268687.23
# 7                       2017-05         3751  520141.45
# 8                       2017-06         3223  430779.58
# 9                       2017-07         3455  455000.99

# %%
plt.figure(figsize=(10, 5)) 
plt.plot(monthly_orders_df["order_delivered_customer_date"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#72BCD4") 
plt.title("Number of Orders per Month (2016-2018)", loc="center", fontsize=20) 
plt.xticks(fontsize=10, rotation=45) 
plt.yticks(fontsize=10) 
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_delivered_customer_date"],
    monthly_orders_df["revenue"],
    marker='o', 
    linewidth=2,
    color="#72BCD4"
)
plt.title("Total Revenue per Month (2016-2018)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=45) 
plt.yticks(fontsize=10) 
plt.show()

# %% [markdown]
# #### Terjadi penurunan jumlah orderan yang sangat signifikan pada bulan agustus tahun 2018, berdampak terhadap penurunan Revenue perusahaan.

# %% [markdown]
# ### Pertanyaan 2: Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?

# %%
product_item_df = pd.merge(
    left=product_item_df,
    right=category_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
sum_order_items_df = product_item_df.groupby("product_category_name_english").order_item_id	.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#    product_category_name_english  order_item_id
# 0                 bed_bath_table          13665
# 1                furniture_decor          11540
# 2                  health_beauty          11081
# 3                 sports_leisure           9932
# 4          computers_accessories           9874
# 5                     housewares           9051
# 6                  watches_gifts           6594
# 7                   garden_tools           5874
# 8                      telephony           5161
# 9                           auto           4881
# 10                          toys           4445
# 11                    cool_stuff           4077
# 12                     perfumery           3785
# 13                          baby           3426
# 14                   electronics           3092

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
 
sns.barplot(x="order_item_id", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)
 
sns.barplot(x="order_item_id", y="product_category_name_english", data=sum_order_items_df.sort_values(by="order_item_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
 
plt.suptitle("Best and Worst Performing Category Product by Number of Sales", fontsize=20)
plt.show()
# Out:
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/2598253284.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_item_id", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/2598253284.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_item_id", y="product_category_name_english", data=sum_order_items_df.sort_values(by="order_item_id", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# #### Berdasarkan gambar di atas, Anda dapat melihat bahwa produk kategori bad bath table merupakan produk yang paling laris. Kontras dengan hal tersebut, produk kategori security and service merupakan produk yang paling sedikit terjual.

# %% [markdown]
# ### Pertanyaan 3: Bagaimana Demografi Pelanggan yang Kita Miliki berdasarkan State?

# %%
bystate_df = customers_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 10))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count", 
    y="customer_state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/1249599838.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/1249599838.py:8: UserWarning:
# The palette list has fewer values (8) than needed (27) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %% [markdown]
# #### Berdasarkan visualisasi data tersebut, dapat diketahui bahwa pelanggan yang kita miliki paling banyak berasal dari State SP.

# %% [markdown]
# ### Pertanyaan 4: Tipe pembayaran jenis apa yang paling banyak digunakan pelanggan?

# %%
# Mengelompokkan dataset berdasarkan payment_type dan menghitung jumlah order_id yang unik
payment_type_counts = payments_df.groupby('payment_type')['order_id'].nunique()

# Membuat pie chart
plt.figure(figsize=(10, 10))
payment_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=30, colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6', '#c4e17f']
)
plt.title('Persentase Tipe Pembayaran')
plt.ylabel('')  # Menghilangkan label y-axis
plt.xticks(fontsize=10, rotation=45) 
plt.show()

# %% [markdown]
# #### Pelanggan paling banyak menggunakan tipe pembayaran credit card, dengan persentase 75.2%

# %% [markdown]
# ### Pertanyaan 5: Seberapa puas pelanggan dalam menggunakan layanan?

# %%
review_score_counts = review_df.groupby('review_score')['order_id'].nunique()

# Membuat bar chart
plt.figure(figsize=(8, 6))
review_score_counts.plot(kind='bar', color='skyblue')

# Menambahkan judul dan label
plt.title('Distribusi Review Score Berdasarkan Jumlah Order', fontsize=14, weight='bold')
plt.xlabel('Review Score', fontsize=12)
plt.ylabel('Jumlah Order ID', fontsize=12)

# Menampilkan chart
plt.xticks(rotation=0)  # Memastikan label x-axis horizontal
plt.show()

# %% [markdown]
# #### Pelanggan sangat puas dalam menggunakan layanan, dapat dilihat pada bar chart diatas, kebanyakan pelanggan memberikan review score 5

# %% [markdown]
# ### Pertanyaan 6: Berapa banyak pengiriman barang yang terlambat?

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Mengelompokkan data berdasarkan 'is_late_delivery' dan menghitung jumlah order_id yang unik
pengiriman_terlambat = order_df.groupby('is_late_delivery')['order_id'].nunique()

# Menentukan warna untuk masing-masing nilai True dan False
colors = ['grey' if x == False else 'red' for x in pengiriman_terlambat.index]

# Membuat bar chart
plt.figure(figsize=(8, 6))
ax = pengiriman_terlambat.plot(kind='bar', color=colors)

# Menambahkan judul dan label
plt.title('Keterlambatan dalam Pengiriman', fontsize=14, weight='bold')
plt.xlabel('Terlambat', fontsize=12)
plt.ylabel('')  # Menghapus label y-axis

# Menambahkan angka di atas setiap bar
for i, v in enumerate(pengiriman_terlambat):
    ax.text(i, v + 0.3, str(v), ha='center', fontsize=12, weight='bold')

# Menampilkan chart
plt.xticks(rotation=0)  # Memastikan label x-axis horizontal
plt.show()

# %% [markdown]
# #### Sebanyak 7826 order terlambat sampai ke pelanggan.

# %% [markdown]
# ## Analisis Lanjutan (Opsional) : RFM Analysis

# %%
revenue_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                             110180                            110180
# unique                             96461                             96461
# top     8272b63d03f5f79c56e9e4120aec44ef  fc3d1daec319d62d49bfb5e1f83123e9
# freq                                  21                                21
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
rfm_df = revenue_df.groupby(by="customer_id", as_index=False).agg({
    "order_delivered_customer_date": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
rfm_df.head()
# Out:
#                         customer_id max_order_timestamp  frequency  monetary
# 0  00012a2ce6f8dcda20d059ce98491703 2017-11-28 15:41:30          1     89.80
# 1  000161a058600d5901f007fab4c27140 2017-07-25 18:57:33          1     54.90
# 2  0001fd6190edaaf884bcaf3d49edf079 2017-03-06 08:57:49          1    179.99
# 3  0002414f95344307404f0ace7a26f1d5 2017-09-13 20:06:02          1    149.90
# 4  000379cdec625522490c315e70c7a9fb 2018-04-13 20:21:08          1     93.00

# %%
rfm_df.describe(include="all")
# Out:
#                              customer_id            max_order_timestamp  \
# count                              96461                          96461
# unique                             96461                            NaN
# top     00012a2ce6f8dcda20d059ce98491703                            NaN
# freq                                   1                            NaN
# mean                                 NaN  2018-01-14 13:17:13.228102400
# min                                  NaN            2016-10-11 13:46:32
# 25%                                  NaN            2017-09-25 22:31:59
# 50%                                  NaN            2018-02-02 19:50:56
# 75%                                  NaN            2018-05-15 23:08:54
# max                                  NaN            2018-10-17 13:22:46
# std                                  NaN                            NaN
#
#         frequency      monetary
# count     96461.0  96461.000000
# unique        NaN           NaN
# ...

# %%
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = revenue_df["order_delivered_customer_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
 
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      323
# 1  000161a058600d5901f007fab4c27140          1     54.90      449
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      590
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      399
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      187

# %%
rfm_df.sort_values(by="recency", ascending=True).head(5)
# Out:
#                             customer_id  frequency  monetary  recency
# 1265   033fab69968b0d69099d64423831a236          1     26.40        0
# 14988  27ae7c8a8fc20ce80d96f01b6f19961b          1    179.00        6
# 59756  9e83d47684eb1a58b1c31830f5de10ac          1     70.00       15
# 96330  ffa87b4246c4848711afb512bd51f161          1    209.99       20
# 7499   1409b2945191b7aff1975ba2ce9918c5          1     49.90       22

# %%
rfm_df.sort_values(by="frequency", ascending=False).head(5)
# Out:
#                             customer_id  frequency  monetary  recency
# 0      00012a2ce6f8dcda20d059ce98491703          1     89.80      323
# 64304  aa5e0a0c36015d39de864189a2b00b09          1     76.00       58
# 64313  aa6190994371836fc1d4596edd827abd          1    210.00      256
# 64312  aa606152f23a5fa9ba3d0b87f7a492e8          1     55.00      261
# 64311  aa601b3c45980c0918042d5ca7a25054          1     49.99      211

# %%
rfm_df.sort_values(by="monetary", ascending=False).head(5)
# Out:
#                             customer_id  frequency  monetary  recency
# 8291   1617b1357756262bfa56ab541c47bc16          1   13440.0      365
# 89260  ec5b2ba62e574342386871631fafd3fc          1    7160.0       83
# 75229  c6e2731c5b391845f6800c97401a43a9          1    6735.0      593
# 92295  f48d464a0baaea338cb25f816991ab1f          1    6729.0       63
# 24061  3fd6777bbce08a352fddd04e4a7cc8f6          1    6499.0      499

# %%
rfm_df.describe(include="all")
# Out:
#                              customer_id  frequency      monetary  \
# count                              96461    96461.0  96461.000000
# unique                             96461        NaN           NaN
# top     00012a2ce6f8dcda20d059ce98491703        NaN           NaN
# freq                                   1        NaN           NaN
# mean                                 NaN        1.0    137.040313
# std                                  NaN        0.0    209.059760
# min                                  NaN        1.0      0.850000
# 25%                                  NaN        1.0     45.900000
# 50%                                  NaN        1.0     86.500000
# 75%                                  NaN        1.0    149.900000
# max                                  NaN        1.0  13440.000000
#
#              recency
# count   96461.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      276.144162
# std       152.164863
# ...

# %% [markdown]
# ### Pertanyaan 7: Kapan terakhir pelanggan melakukan transaksi?
# #### Terakhir kali pelanggan melakukan transaksi hari ini.
#
# ### Pertanyaan 8: Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# #### Pelanggan hanya melakukan 1 kali transaksi.
#
# ### Pertanyaan 9: Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?
# #### Paling banyak 13440 dolar.

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))
 
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
 
# Plot untuk Recency
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=10)
ax[0].tick_params(axis='x', rotation=90)  # Rotasi label 
# Menambahkan angka di atas setiap batang
for p in ax[0].patches:
    ax[0].annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                   textcoords='offset points')

# Plot untuk Frequency
sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=10)
ax[1].tick_params(axis='x', rotation=90)  # Rotasi label 
# Menambahkan angka di atas setiap batang
for p in ax[1].patches:
    ax[1].annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                   textcoords='offset points')

# Plot untuk Monetary
sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=10)
ax[2].tick_params(axis='x', rotation=90)  # Rotasi label
# Menambahkan angka di atas setiap batang
for p in ax[2].patches:
    ax[2].annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                   textcoords='offset points')
    
plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/1595791054.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/1595791054.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/1595791054.py:32: FutureWarning:
#
# ...

# %% [markdown]
# #### Mengurutkan customer berdasarkan recency, frequency, & monetary score

# %%
rfm_df['r_rank'] = rfm_df['recency'].rank(ascending=False)
rfm_df['f_rank'] = rfm_df['frequency'].rank(ascending=True)
rfm_df['m_rank'] = rfm_df['monetary'].rank(ascending=True)

rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency   r_rank  \
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      323  33307.5
# 1  000161a058600d5901f007fab4c27140          1     54.90      449  15632.0
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      590   2194.0
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      399  22329.0
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      187  64102.5
#
#     f_rank   m_rank
# 0  48231.0  49426.0
# 1  48231.0  30662.0
# 2  48231.0  78483.0
# 3  48231.0  72196.0
# 4  48231.0  51816.5

# %%
# normalizing the rank of the customers
rfm_df['r_rank_norm'] = (rfm_df['r_rank']/rfm_df['r_rank'].max())*100
rfm_df['f_rank_norm'] = (rfm_df['f_rank']/rfm_df['f_rank'].max())*100
rfm_df['m_rank_norm'] = (rfm_df['m_rank']/rfm_df['m_rank'].max())*100
 
rfm_df.drop(columns=['r_rank', 'f_rank', 'm_rank'], inplace=True)
 
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency  \
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      323
# 1  000161a058600d5901f007fab4c27140          1     54.90      449
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      590
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      399
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      187
#
#    r_rank_norm  f_rank_norm  m_rank_norm
# 0    34.529499        100.0    51.239361
# 1    16.205513        100.0    31.786940
# 2     2.274494        100.0    81.362416
# 3    23.148215        100.0    74.844756
# 4    66.454318        100.0    53.717565

# %%
rfm_df['RFM_score'] = 0.15*rfm_df['r_rank_norm']+0.28 * \
    rfm_df['f_rank_norm']+0.57*rfm_df['m_rank_norm']
rfm_df['RFM_score'] *= 0.05
rfm_df = rfm_df.round(2)
rfm_df[['customer_id', 'RFM_score']].head(7)
# Out:
#                         customer_id  RFM_score
# 0  00012a2ce6f8dcda20d059ce98491703       3.12
# 1  000161a058600d5901f007fab4c27140       2.43
# 2  0001fd6190edaaf884bcaf3d49edf079       3.74
# 3  0002414f95344307404f0ace7a26f1d5       3.71
# 4  000379cdec625522490c315e70c7a9fb       3.43
# 5  0004164d20a9e969af783496f3408652       2.51
# 6  000419c5494106c306a97b5635748086       2.38

# %% [markdown]
# #### Segmentasi customer berdasarkan RFM_score

# %%
rfm_df["customer_segment"] = np.where(
    rfm_df['RFM_score'] > 4.5, "Top customers", (np.where(
        rfm_df['RFM_score'] > 4, "High value customer",(np.where(
            rfm_df['RFM_score'] > 3, "Medium value customer", np.where(
                rfm_df['RFM_score'] > 1.6, 'Low value customers', 'lost customers'))))))

rfm_df[['customer_id', 'RFM_score', 'customer_segment']].head(20)
# Out:
#                          customer_id  RFM_score       customer_segment
# 0   00012a2ce6f8dcda20d059ce98491703       3.12  Medium value customer
# 1   000161a058600d5901f007fab4c27140       2.43    Low value customers
# 2   0001fd6190edaaf884bcaf3d49edf079       3.74  Medium value customer
# 3   0002414f95344307404f0ace7a26f1d5       3.71  Medium value customer
# 4   000379cdec625522490c315e70c7a9fb       3.43  Medium value customer
# 5   0004164d20a9e969af783496f3408652       2.51    Low value customers
# 6   000419c5494106c306a97b5635748086       2.38    Low value customers
# 7   00046a560d407e99b969756e0b10f282       3.61  Medium value customer
# 8   00050bf6e01e69d5c0fd612f1bcfb69c       2.82    Low value customers
# 9   000598caf2ef4117407665ac33275130       4.95          Top customers
# 10  0005aefbb696d34b3424dccd0a0e9fd0       4.03    High value customer
# 11  00062b33cb9f6fe976afdcff967ea74d       2.17    Low value customers
# ...

# %%
customer_segment_df = rfm_df.groupby(by="customer_segment", as_index=False).customer_id.nunique()
customer_segment_df
# Out:
#         customer_segment  customer_id
# 0    High value customer        15670
# 1    Low value customers        40565
# 2  Medium value customer        33662
# 3          Top customers         5470
# 4         lost customers         1094

# %%
customer_segment_df['customer_segment'] = pd.Categorical(customer_segment_df['customer_segment'], [
    "lost customers", "Low value customers", "Medium value customer",
    "High value customer", "Top customers"
])

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="customer_id", 
    y="customer_segment",
    data=customer_segment_df.sort_values(by="customer_segment", ascending=False),
    palette=colors_
)
plt.title("Number of Customer for Each Segment", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# /var/folders/26/6xwtvhcj77x6tdf1n4nzrw000000gn/T/ipykernel_4285/1016365800.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Mengabungkan semua dataset untuk membuat dashboard

# %%
revenue_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110180 entries, 0 to 110179
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110180 non-null  object
#  1   customer_id                    110180 non-null  object
#  2   order_status                   110180 non-null  object
#  3   order_purchase_timestamp       110180 non-null  datetime64[ns]
#  4   order_approved_at              110180 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   110180 non-null  datetime64[ns]
#  6   order_delivered_customer_date  110180 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  110180 non-null  datetime64[ns]
#  8   is_late_delivery               110180 non-null  bool
#  9   order_item_id                  110180 non-null  int64
#  10  product_id                     110180 non-null  object
# ...

# %%
product_item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  object
#  3   seller_id                      112650 non-null  object
#  4   shipping_limit_date            112650 non-null  datetime64[ns]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   product_category_name          111046 non-null  object
#  8   product_category_name_english  111022 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 7.7+ MB

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
#  5   status                    99441 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 4.6+ MB

# %%
payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
#  5   total_payment         103886 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ MB

# %%
all_df = pd.merge(
    left=revenue_df,
    right=product_item_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153858 entries, 0 to 153857
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       153858 non-null  object
#  1   customer_id                    153858 non-null  object
#  2   order_status                   153858 non-null  object
#  3   order_purchase_timestamp       153858 non-null  datetime64[ns]
#  4   order_approved_at              153858 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   153858 non-null  datetime64[ns]
#  6   order_delivered_customer_date  153858 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  153858 non-null  datetime64[ns]
#  8   is_late_delivery               153858 non-null  bool
#  9   order_item_id_x                153858 non-null  int64
#  10  product_id_x                   153858 non-null  object
# ...

# %%
all_df = pd.merge(
    left=all_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153858 entries, 0 to 153857
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       153858 non-null  object
#  1   customer_id                    153858 non-null  object
#  2   order_status                   153858 non-null  object
#  3   order_purchase_timestamp       153858 non-null  datetime64[ns]
#  4   order_approved_at              153858 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   153858 non-null  datetime64[ns]
#  6   order_delivered_customer_date  153858 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  153858 non-null  datetime64[ns]
#  8   is_late_delivery               153858 non-null  bool
#  9   order_item_id_x                153858 non-null  int64
#  10  product_id_x                   153858 non-null  object
# ...

# %%
all_df = pd.merge(
    left=all_df,
    right=payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160207 entries, 0 to 160206
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       160207 non-null  object
#  1   customer_id                    160207 non-null  object
#  2   order_status                   160207 non-null  object
#  3   order_purchase_timestamp       160207 non-null  datetime64[ns]
#  4   order_approved_at              160207 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   160207 non-null  datetime64[ns]
#  6   order_delivered_customer_date  160207 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  160207 non-null  datetime64[ns]
#  8   is_late_delivery               160207 non-null  bool
#  9   order_item_id_x                160207 non-null  int64
#  10  product_id_x                   160207 non-null  object
# ...

# %%
all_df = pd.merge(
    left=all_df,
    right=review_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161312 entries, 0 to 161311
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       161312 non-null  object
#  1   customer_id                    161312 non-null  object
#  2   order_status                   161312 non-null  object
#  3   order_purchase_timestamp       161312 non-null  datetime64[ns]
#  4   order_approved_at              161312 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   161312 non-null  datetime64[ns]
#  6   order_delivered_customer_date  161312 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  161312 non-null  datetime64[ns]
#  8   is_late_delivery               161312 non-null  bool
#  9   order_item_id_x                161312 non-null  int64
#  10  product_id_x                   161312 non-null  object
# ...

# %%
all_df = all_df.rename(columns={
    "order_delivered_customer_date": "order_date",
    "product_category_name_english": "product_name",
    "price_x": "total_price",
    "order_delivered_carrier_date": "delivery_date",
    "order_item_id_x" : "quantity_x",
    "customer_state" : "state"
    
})

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161312 entries, 0 to 161311
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       161312 non-null  object
#  1   customer_id                    161312 non-null  object
#  2   order_status                   161312 non-null  object
#  3   order_purchase_timestamp       161312 non-null  datetime64[ns]
#  4   order_approved_at              161312 non-null  datetime64[ns]
#  5   delivery_date                  161312 non-null  datetime64[ns]
#  6   order_date                     161312 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  161312 non-null  datetime64[ns]
#  8   is_late_delivery               161312 non-null  bool
#  9   quantity_x                     161312 non-null  int64
#  10  product_id_x                   161312 non-null  object
# ...

# %%
all_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1: Terjadi penurunan penjualan pada bulan agustus tahun 2018.
# - Conclution pertanyaan 2: Produk kategori bad bath table merupakan produk yang paling laris. Kontras dengan hal tersebut, produk kategori security and service merupakan produk yang paling sedikit terjual.
# - Conclution pertanyaan 3: Pelanggan yang kita miliki paling banyak berasal dari State SP.
# - Conclution pertanyaan 4: Pelanggan paling banyak menggunakan tipe pembayaran credit card, dengan persentase 75.2%
# - Conclution pertanyaan 5: Pelanggan sangat puas dalam menggunakan layanan, dapat dilihat pada bar chart diatas, kebanyakan pelanggan memberikan review score 5
# - Conclution pertanyaan 6: Sebanyak 7826 order terlambat sampai ke pelanggan.
# - Conclution pertanyaan 7: Terakhir kali pelanggan melakukan transaksi hari ini.
# - Conclution pertanyaan 8: Pelanggan hanya melakukan 1 kali transaksi.
# - Conclution pertanyaan 9: Paling banyak 13440 dolar.
